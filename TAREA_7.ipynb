# %%
SUMPAR=0
SUMIMP=0
CUEPAR=0
num=0
i = 1
while i <= 270:
    num = i
    if num > 0:
        if num%2!=0:
             SUMPAR = SUMPAR + NUM
             CUEPAR = CUEPAR+1
        else: SUMIMP = SUMIMP+NUM
    i = i+1
PROPAR = SUMPAR/CUEPAR
print(f"Promedio de pares {PROPAR} Suma impar {SUMIMP}")
# Out:
# Promedio de pares 0.0 Suma impar 0

# %%
#3.2
BAND = 'T'
SUMSER = 0
i = 2
while i <= 1800:
    SUMSER =SUMSER+1
    print(i)
    if BAND == 'T':
        BAND = 'F' 
        i = i+3
    else:
        BAND = 'T' 
        i = i+2
print(SUMSER)

# %%
N = int(input("DAME UN NUMERO"))
BAND = 'T'
SERIE = 0
i= 1
while i <= N :
    if BAND == 'T':
        SERIE = SERIE+(1/i)
        BAND= 'F'
    else:
        SERIE= SERIE-(1/i)
        BAND= 'T'
    i=i+1
print(SERIE)
# Out:
# DAME UN NUMERO7
# 0.7595238095238095

# %%
NOM=0
SUE= [750,570,899,900,-1]
i=0
while SUE[i] > -1 :
    if SUE[i] < 1000:
       NSUE= SUE[i]*1.15,2
    else:
        MSUE=SUE[i]*1.12,2
    NOM=NOM+NSUE
    i=1+1
       print(NOM)
  print(NSUE)
# Out:
#   File "<ipython-input-177-f353a8ea16fc>", line 12
#     print(NOM)
#     ^
# IndentationError: unexpected indent
